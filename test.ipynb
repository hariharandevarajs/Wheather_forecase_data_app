# %%
import pandas as pd
df=pd.read_csv("happy.csv")
df['country']
# Out:
# 0                     Niger
# 1                Mozambique
# 2                   Liberia
# 3                    Malawi
# 4                      Chad
#                ...
# 140    United Arab Emirates
# 141             Switzerland
# 142                 Ireland
# 143               Singapore
# 144              Luxembourg
# Name: country, Length: 145, dtype: str
